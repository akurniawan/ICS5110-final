# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot

# %%
analysis_df = pd.read_csv("sklearn_performance.csv")

# %%
sns.set(font_scale=1.5)
a4_dims = (10, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
g = sns.boxplot(data=analysis_df, x="meta", y="test_f1_micro")
# g.set_xlim([0.8, 0.95]) # turn this on to set the limit as you wish
pyplot.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'LogisticRegression-CountVectorizer-None-None'),
#   Text(1, 0, 'LogisticRegression-TfidfVectorizer-None-None'),
#   Text(2, 0, 'LogisticRegression-CountVectorizer-Normalizer-None'),
#   Text(3, 0, 'LogisticRegression-TfidfVectorizer-Normalizer-None'),
#   Text(4, 0, 'LogisticRegression-CountVectorizer-None-TruncatedSVD'),
#   Text(5, 0, 'LogisticRegression-TfidfVectorizer-None-TruncatedSVD'),
#   Text(6, 0, 'MultinomialNB-CountVectorizer-None-None')])

# %%
analysis_df = pd.read_csv("scratch_performance.csv")

# %%
sns.set(font_scale=1.5)
a4_dims = (10, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
g = sns.boxplot(data=analysis_df, x="meta", y="test_f1_micro")
# g.set_xlim([0.8, 0.95]) # turn this on to set the limit as you wish
pyplot.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'SoftmaxRegression-CountVectorizer-None-None'),
#   Text(1, 0, 'SoftmaxRegression-TfidfVectorizer-None-None'),
#   Text(2, 0, 'SoftmaxRegression-CountVectorizer-Normalizer-None'),
#   Text(3, 0, 'SoftmaxRegression-TfidfVectorizer-Normalizer-None'),
#   Text(4, 0, 'SoftmaxRegression-CountVectorizer-None-TruncatedSVD'),
#   Text(5, 0, 'SoftmaxRegression-TfidfVectorizer-None-TruncatedSVD'),
#   Text(6, 0, 'NaiveBayesClassification-CountVectorizer-None-None')])

# %%
analysis_df = pd.read_csv("all_scratch_performance.csv")

# %%
sns.set(font_scale=1.5)
a4_dims = (10, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
g = sns.boxplot(data=analysis_df, x="meta", y="test_f1_micro")
# g.set_xlim([0.8, 0.95]) # turn this on to set the limit as you wish
pyplot.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'SoftmaxRegression-build_count_vector-None-None'),
#   Text(1, 0, 'SoftmaxRegression-build_tfidf_vector-None-None'),
#   Text(2, 0, 'SoftmaxRegression-build_count_vector-normalize-None'),
#   Text(3, 0, 'SoftmaxRegression-build_tfidf_vector-normalize-None'),
#   Text(4, 0, 'SoftmaxRegression-build_count_vector-None-TruncatedSVD'),
#   Text(5, 0, 'SoftmaxRegression-build_tfidf_vector-None-TruncatedSVD'),
#   Text(6, 0, 'NaiveBayesClassification-build_count_vector-None-None')])
