# %%
import pandas as pd
import re
import math
import nltk
import numpy as np
import spacy
import seaborn as sns
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from datetime import datetime
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from collections import Counter
from matplotlib import pyplot
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
df = pd.read_csv("yelp_review_sentiment.tsv", delimiter="\t")
df = df.dropna()

# %%
en_stopwords = stopwords.words('english') + ["-pron-", "pron"]
tmp_df = df.sample(n=220000)

# %%
word_names = cnt_vec.get_feature_names()
word_freq = dict([(word, freq) for word, freq in zip(word_names, counts)])

# %%
wordcloud = WordCloud().generate_from_frequencies(word_freq)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
words = []
for idx, row in df.iterrows():
    words.extend(str(row["text"]).split(" "))
counter = Counter(words)
len(counter)
# Out:
# 914338

# %%
a4_dims = (17, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
g = sns.barplot(data=pd.DataFrame(counter.most_common(100), columns=["word", "freq"]), x="word", y="freq", ax=ax)
g.set_xticklabels(labels=g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '-pron-'),
#  Text(1, 0, 'be'),
#  Text(2, 0, 'the'),
#  Text(3, 0, 'and'),
#  Text(4, 0, 'i'),
#  Text(5, 0, 'to'),
#  Text(6, 0, 'a'),
#  Text(7, 0, 'not'),
#  Text(8, 0, 'have'),
#  Text(9, 0, 'of'),
#  Text(10, 0, 'for'),
#  Text(11, 0, 'in'),
#  Text(12, 0, 'that'),
#  Text(13, 0, 'do'),
#  Text(14, 0, 'but'),
#  Text(15, 0, 'this'),
#  Text(16, 0, 'with'),
#  Text(17, 0, 'on'),
#  Text(18, 0, 'get'),
#  Text(19, 0, 'at'),
#  Text(20, 0, 'so'),
#  Text(21, 0, 'go'),
#  Text(22, 0, 'good'),
#  Text(23, 0, 'food'),
#  Text(24, 0, 'place'),
#  Text(25, 0, 'there'),
#  Text(26, 0, 'time'),
#  Text(27, 0, 'order'),
#  Text(28, 0, 'as'),
#  Text(29, 0, 'come'),
#  Text(30, 0, 'would'),
#  Text(31, 0, 'out'),
#  Text(32, 0, 'if'),
#  Text(33, 0, 'very'),
#  Text(34, 0, 'service'),
#  Text(35, 0, 'like'),
#  Text(36, 0, 'just'),
#  Text(37, 0, 'all'),
#  Text(38, 0, 'one'),
#  Text(39, 0, 'when'),
#  Text(40, 0, 'here'),
#  Text(41, 0, 'say'),
#  Text(42, 0, 'back'),
#  Text(43, 0, 'will'),
#  Text(44, 0, 'up'),
#  Text(45, 0, 'no'),
#  Text(46, 0, 'or'),
#  Text(47, 0, 'from'),
#  Text(48, 0, 'make'),
#  Text(49, 0, 'take'),
#  Text(50, 0, 'an'),
#  Text(51, 0, 'well'),
#  Text(52, 0, 'great'),
#  Text(53, 0, 'can'),
#  Text(54, 0, 'about'),
#  Text(55, 0, 'what'),
#  Text(56, 0, 'try'),
#  Text(57, 0, 'because'),
#  Text(58, 0, 'which'),
#  Text(59, 0, 'give'),
#  Text(60, 0, 'ask'),
#  Text(61, 0, 'really'),
#  Text(62, 0, 'only'),
#  Text(63, 0, 'tell'),
#  Text(64, 0, 'wait'),
#  Text(65, 0, 'other'),
#  Text(66, 0, 'more'),
#  Text(67, 0, 'could'),
#  Text(68, 0, 'even'),
#  Text(69, 0, 'after'),
#  Text(70, 0, 'want'),
#  Text(71, 0, 'by'),
#  Text(72, 0, 'look'),
#  Text(73, 0, 'some'),
#  Text(74, 0, 'also'),
#  Text(75, 0, 'restaurant'),
#  Text(76, 0, 'call'),
#  Text(77, 0, 'never'),
#  Text(78, 0, 'bad'),
#  Text(79, 0, 'see'),
#  Text(80, 0, 'then'),
#  Text(81, 0, 'know'),
#  Text(82, 0, 'over'),
#  Text(83, 0, 'price'),
#  Text(84, 0, 'nice'),
#  Text(85, 0, 'first'),
#  Text(86, 0, 'too'),
#  Text(87, 0, 'customer'),
#  Text(88, 0, 'think'),
#  Text(89, 0, 'eat'),
#  Text(90, 0, 'day'),
#  Text(91, 0, 'need'),
#  Text(92, 0, 'again'),
#  Text(93, 0, 'work'),
#  Text(94, 0, 'minute'),
#  Text(95, 0, 'experience'),
#  Text(96, 0, 'people'),
#  Text(97, 0, 'drink'),
#  Text(98, 0, 'chicken'),
#  Text(99, 0, 'staff')]

# %%
en_stopwords = stopwords.words('english') + ["-pron-"]
words = []
for idx, row in df.iterrows():
    words.extend([word for word in str(row["text"]).split(" ") if word not in en_stopwords])
counter = Counter(words)
len(counter)

# %%
a4_dims = (17, 7)
fig, ax = pyplot.subplots(figsize=a4_dims)
g = sns.barplot(data=pd.DataFrame(counter.most_common(100), columns=["word", "freq"]), x="word", y="freq", ax=ax)
g.set_xticklabels(labels=g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'get'),
#  Text(1, 0, 'go'),
#  Text(2, 0, 'good'),
#  Text(3, 0, 'food'),
#  Text(4, 0, 'place'),
#  Text(5, 0, 'time'),
#  Text(6, 0, 'order'),
#  Text(7, 0, 'come'),
#  Text(8, 0, 'would'),
#  Text(9, 0, 'service'),
#  Text(10, 0, 'like'),
#  Text(11, 0, 'one'),
#  Text(12, 0, 'say'),
#  Text(13, 0, 'back'),
#  Text(14, 0, 'make'),
#  Text(15, 0, 'take'),
#  Text(16, 0, 'well'),
#  Text(17, 0, 'great'),
#  Text(18, 0, 'try'),
#  Text(19, 0, 'give'),
#  Text(20, 0, 'ask'),
#  Text(21, 0, 'really'),
#  Text(22, 0, 'tell'),
#  Text(23, 0, 'wait'),
#  Text(24, 0, 'could'),
#  Text(25, 0, 'even'),
#  Text(26, 0, 'want'),
#  Text(27, 0, 'look'),
#  Text(28, 0, 'also'),
#  Text(29, 0, 'restaurant'),
#  Text(30, 0, 'call'),
#  Text(31, 0, 'never'),
#  Text(32, 0, 'bad'),
#  Text(33, 0, 'see'),
#  Text(34, 0, 'know'),
#  Text(35, 0, 'price'),
#  Text(36, 0, 'nice'),
#  Text(37, 0, 'first'),
#  Text(38, 0, 'customer'),
#  Text(39, 0, 'think'),
#  Text(40, 0, 'eat'),
#  Text(41, 0, 'day'),
#  Text(42, 0, 'need'),
#  Text(43, 0, 'work'),
#  Text(44, 0, 'minute'),
#  Text(45, 0, 'experience'),
#  Text(46, 0, 'people'),
#  Text(47, 0, 'drink'),
#  Text(48, 0, 'chicken'),
#  Text(49, 0, 'staff'),
#  Text(50, 0, 'table'),
#  Text(51, 0, 'taste'),
#  Text(52, 0, 'much'),
#  Text(53, 0, 'leave'),
#  Text(54, 0, 'find'),
#  Text(55, 0, 'pay'),
#  Text(56, 0, 'love'),
#  Text(57, 0, 'thing'),
#  Text(58, 0, 'use'),
#  Text(59, 0, 'two'),
#  Text(60, 0, '2'),
#  Text(61, 0, 'way'),
#  Text(62, 0, 'feel'),
#  Text(63, 0, 'little'),
#  Text(64, 0, 'still'),
#  Text(65, 0, 'menu'),
#  Text(66, 0, 'hour'),
#  Text(67, 0, 'another'),
#  Text(68, 0, 'location'),
#  Text(69, 0, 'pretty'),
#  Text(70, 0, 'star'),
#  Text(71, 0, 'always'),
#  Text(72, 0, 'room'),
#  Text(73, 0, 'new'),
#  Text(74, 0, 'check'),
#  Text(75, 0, 'long'),
#  Text(76, 0, 'seem'),
#  Text(77, 0, 'server'),
#  Text(78, 0, 'review'),
#  Text(79, 0, 'friendly'),
#  Text(80, 0, 'lot'),
#  Text(81, 0, 'around'),
#  Text(82, 0, 'definitely'),
#  Text(83, 0, '3'),
#  Text(84, 0, 'recommend'),
#  Text(85, 0, 'walk'),
#  Text(86, 0, 'sure'),
#  Text(87, 0, 'small'),
#  Text(88, 0, 'right'),
#  Text(89, 0, 'sauce'),
#  Text(90, 0, 'year'),
#  Text(91, 0, 'sit'),
#  Text(92, 0, 'since'),
#  Text(93, 0, 'fry'),
#  Text(94, 0, 'night'),
#  Text(95, 0, 'ever'),
#  Text(96, 0, 'friend'),
#  Text(97, 0, 'pizza'),
#  Text(98, 0, 'bar'),
#  Text(99, 0, 'last')]
